# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fetal-detection-and-test/test_set/test_set/245_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/211_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/247_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/137_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/72_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/213_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/253_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/221_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/78_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/46_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/120_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/123_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/33_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/105_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/329_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/288_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/114_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/170_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/227_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/118_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/229_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/183_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/142_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/68_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/293_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/323_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/219_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/153_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/328_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/285_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/226_4HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/263_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/99_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/52_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/298_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/98_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/220_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/70_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/163_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/276_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/333_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/106_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/27_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/124_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/149_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/110_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/176_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/93_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/88_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/332_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/224_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/237_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/147_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/322_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/242_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/187_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/86_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/278_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/90_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/19_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/283_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/265_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/228_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/209_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/273_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/92_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/274_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/303_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/231_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/292_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/302_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/28_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/61_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/196_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/146_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/257_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/335_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/64_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/256_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/34_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/203_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/216_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/281_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/136_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/84_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/157_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/155_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/191_4HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/171_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/59_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/334_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/202_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/132_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/109_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/313_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/75_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/320_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/128_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/173_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/177_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/10_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/270_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/304_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/174_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/324_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/112_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/222_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/148_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/7_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/60_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/284_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/172_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/159_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/85_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/87_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/182_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/32_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/268_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/20_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/121_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/44_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/330_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/15_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/107_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/290_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/277_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/208_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/262_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/169_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/62_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/248_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/108_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/250_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/225_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/102_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/119_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/306_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/179_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/83_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/289_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/55_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/243_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/282_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/45_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/18_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/156_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/309_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/327_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/49_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/53_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/165_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/21_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/42_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/218_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/190_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/300_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/251_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/316_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/81_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/259_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/95_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/30_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/43_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/271_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/154_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/82_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/56_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/50_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/275_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/266_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/158_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/47_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/299_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/2_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/252_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/67_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/319_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/308_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/296_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/181_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/79_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/235_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/37_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/127_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/39_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/80_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/91_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/131_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/249_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/12_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/279_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/301_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/215_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/180_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/104_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/189_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/130_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/291_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/35_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/11_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/135_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/134_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/4_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/9_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/162_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/178_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/16_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/126_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/29_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/6_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/280_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/113_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/22_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/234_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/269_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/317_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/186_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/8_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/24_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/185_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/205_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/38_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/143_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/307_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/239_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/294_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/287_4HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/140_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/103_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/204_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/101_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/65_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/325_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/25_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/73_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/151_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/3_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/267_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/201_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/Thumbs.db
# /kaggle/input/fetal-detection-and-test/test_set/test_set/212_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/23_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/40_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/255_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/100_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/236_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/116_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/138_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/166_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/295_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/305_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/74_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/238_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/331_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/193_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/310_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/5_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/89_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/115_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/150_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/206_6HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/230_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/195_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/77_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/66_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/144_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/246_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/314_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/41_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/94_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/145_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/164_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/133_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/200_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/36_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/311_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/71_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/207_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/272_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/175_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/1_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/57_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/198_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/318_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/122_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/69_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/13_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/63_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/129_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/51_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/286_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/96_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/167_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/161_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/117_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/258_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/217_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/321_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/48_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/194_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/297_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/223_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/76_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/168_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/241_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/261_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/188_3HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/54_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/264_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/199_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/184_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/210_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/214_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/160_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/232_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/26_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/254_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/97_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/260_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/125_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/326_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/31_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/17_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/152_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/139_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/111_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/312_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/14_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/197_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/244_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/58_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/141_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/240_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/192_2HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/315_HC.png
# /kaggle/input/fetal-detection-and-test/test_set/test_set/233_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/245_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/531_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/237_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/933_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/449_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/862_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/244_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/36_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/557_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/259_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/691_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/215_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/442_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/93_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/563_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/770_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/137_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/506_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/350_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/498_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/72_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/47_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/738_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/460_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/376_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/894_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/213_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/829_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/549_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/801_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/539_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/428_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/491_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/20_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/769_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/908_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/982_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/840_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/956_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/221_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/72_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/864_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/468_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/987_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/558_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/412_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/78_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/419_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/119_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/935_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/46_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/811_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/325_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/777_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/23_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/522_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/940_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/501_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/675_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/662_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/495_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/83_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/304_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/591_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/274_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/505_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/728_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/114_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/408_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/783_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/120_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/952_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/657_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/170_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/517_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/799_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/123_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/33_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/678_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/976_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/397_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/718_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/863_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/475_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/81_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/11_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/329_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/288_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/886_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/965_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/443_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/917_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/974_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/929_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/992_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/478_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/461_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/680_3HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/209_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/526_4HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/938_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/430_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/659_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/18_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/91_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/510_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/322_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/436_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/170_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/427_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/792_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/281_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/303_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/754_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/227_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/937_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/417_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/118_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/716_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/103_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/969_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/607_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/980_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/737_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/229_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/284_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/183_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/386_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/789_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/679_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/686_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/132_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/108_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/723_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/161_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/441_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/882_7HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/833_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/68_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/572_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/494_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/293_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/707_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/323_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/219_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/966_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/614_3HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/454_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/153_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/584_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/833_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/979_4HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/746_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/366_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/963_4HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/934_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/685_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/328_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/761_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/154_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/855_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/513_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/881_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/42_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/309_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/735_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/285_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/640_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/112_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/822_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/375_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/263_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/687_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/458_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/7_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/120_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/758_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/52_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/861_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/155_3HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/626_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/900_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/149_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/860_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/518_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/923_4HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/946_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/553_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/971_4HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/924_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/570_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/390_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/674_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/440_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/855_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/691_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/425_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/98_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/220_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/184_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/453_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/362_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/674_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/163_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/622_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/998_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/276_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/852_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/106_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/243_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/995_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/976_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/812_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/804_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/359_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/871_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/498_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/881_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/932_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/950_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/24_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/859_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/817_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/828_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/154_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/922_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/977_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/755_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/925_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/484_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/448_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/207_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/518_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/736_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/410_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/129_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/766_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/522_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/59_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/806_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/382_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/887_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/191_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/573_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/44_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/174_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/572_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/230_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/110_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/280_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/186_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/311_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/972_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/537_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/93_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/692_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/968_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/909_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/88_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/373_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/837_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/831_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/795_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/915_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/279_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/712_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/467_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/939_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/15_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/973_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/625_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/229_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/795_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/854_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/424_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/813_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/830_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/205_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/520_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/832_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/879_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/699_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/479_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/332_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/195_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/24_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/493_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/899_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/219_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/565_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/982_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/958_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/867_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/145_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/500_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/681_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/411_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/524_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/402_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/725_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/221_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/878_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/288_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/560_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/2_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/147_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/444_HC_Annotation.png
# ...
# /kaggle/input/fetal-detection-and-test/training_set/training_set/41_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/743_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/927_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/695_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/612_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/850_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/754_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/291_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/578_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/556_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/823_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/199_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/762_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/624_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/515_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/134_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/404_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/210_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/616_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/214_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/568_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/125_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/883_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/109_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/623_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/877_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/439_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/885_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/465_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/971_4HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/933_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/694_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/105_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/406_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/100_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/869_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/599_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/138_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/232_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/26_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/714_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/447_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/347_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/567_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/97_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/809_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/361_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/794_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/774_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/775_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/289_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/395_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/420_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/299_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/365_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/430_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/260_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/43_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/802_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/831_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/9_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/642_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/945_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/321_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/202_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/751_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/245_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/54_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/455_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/142_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/326_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/292_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/31_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/873_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/707_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/149_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/344_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/49_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/731_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/627_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/165_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/264_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/878_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/166_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/883_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/596_3HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/638_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/403_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/358_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/147_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/621_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/102_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/991_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/74_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/603_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/714_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/242_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/931_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/1_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/923_4HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/684_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/577_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/489_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/820_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/620_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/719_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/70_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/241_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/105_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/937_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/33_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/530_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/485_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/137_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/874_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/759_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/139_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/773_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/591_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/71_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/182_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/111_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/611_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/312_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/14_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/687_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/546_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/444_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/722_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/509_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/222_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/782_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/424_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/909_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/970_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/724_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/197_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/167_3HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/803_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/79_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/188_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/689_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/447_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/655_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/736_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/556_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/660_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/668_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/244_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/332_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/571_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/58_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/948_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/158_3HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/595_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/141_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/240_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/463_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/55_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/675_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/110_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/540_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/840_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/621_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/615_4HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/548_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/690_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/231_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/249_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/939_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/173_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/186_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/973_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/625_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/954_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/69_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/729_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/383_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/800_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/713_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/639_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/114_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/943_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/247_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/133_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/734_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/405_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/27_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/913_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/315_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/233_HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/874_2HC.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/961_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/152_2HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/594_HC_Annotation.png
# /kaggle/input/fetal-detection-and-test/training_set/training_set/944_2HC_Annotation.png

# %%
path2data = "../input/fetal-detection-and-test/training_set/training_set"

img_list = [i for i in os.listdir(path2data) if i.find("Annotation") is -1 and i.endswith(".png")]
ann_list = [i for i in os.listdir(path2data) if i.find("Annotation") is not -1]

print(f"# Img list: {len(img_list)}")

print(f"# Annotation list: {len(ann_list)}")
# Out:
# # Img list: 999
# # Annotation list: 999

# %%
np.random.seed(2019)
rnd_list = np.random.choice(img_list, 3)
rnd_list
# Out:
# array(['584_HC.png', '169_HC.png', '741_HC.png'], dtype='<U11')

# %%
import matplotlib.pyplot as plt
from PIL import Image
from scipy import ndimage as ndi
from skimage.segmentation import mark_boundaries

# %%
def show_img_mask(img,mask):
    img_mask=mark_boundaries(np.array(img), np.array(mask, dtype = np.bool), outline_color=(0,1,0), color=(0,1,0))
    plt.imshow(img_mask)

# %%
for i in rnd_list:
    path2img = os.path.join(path2data,i)
    path2ann = path2img.replace(".png", "_Annotation.png")
    img = Image.open(path2img)
    annt_edges = Image.open(path2ann)
    mask = ndi.binary_fill_holes(annt_edges)
    
    plt.figure(figsize= (10,10))
    plt.subplot(1,3,1)
    plt.imshow(img, cmap="gray")
    
    
    plt.subplot(1,3,2)
    plt.imshow(mask, cmap="gray")
    
    
    plt.subplot(1,3,3)
    mask = mask*1
    show_img_mask(img,mask)

# %%
# !conda install -c conda-forge imgaug --yes
# !conda install -c albumentations -c albumentations --yes

# %%
from albumentations import (
HorizontalFlip,
VerticalFlip,
Compose,
Resize
)

# %%
h,w = 128,192
transform_train = Compose([
    Resize(h,w),
    HorizontalFlip(p = 0.5),
    VerticalFlip(p = 0.5)
])

transform_val = Resize(h,w)

# %%
from torch.utils.data import Dataset
from PIL import Image
from torchvision.transforms.functional import to_tensor, to_pil_image
import torch

# %%
class fetal_dataset(Dataset):
    def __init__(self, path2data, transform= None):
        img_list = [i for i in os.listdir(path2data) if i.find("Annotation") is -1 and i.endswith(".png")]
        ann_list = [i for i in os.listdir(path2data) if i.find("Annotation") is not -1]
        
        self.path2imgs = [os.path.join(path2data, fn) for fn in img_list]
        
        self.path2annts = [p2i.replace(".png", "_Annotation.png") for p2i in self.path2imgs]
        
        self.transform = transform
        
    def __len__(self):
        return len(self.path2imgs)
    
    def __getitem__(self,idx):
        
        path2img = self.path2imgs[idx]
        image = Image.open(path2img)
        
        path2annt = self.path2annts[idx]
        annt_edges = Image.open(path2annt)
        
        mask = ndi.binary_fill_holes(annt_edges)
        image = np.array(image)
        mask = mask.astype("uint8")
        
        if self.transform:
            augmented = self.transform(image = image, mask = mask)
            image = augmented['image']
            mask = augmented['mask']
            
        image = to_tensor(image)
        mask = 255*to_tensor(mask)
        
        return image, mask

# %%
fetal_ds1 = fetal_dataset(path2data, transform = transform_train)
fetal_ds2 = fetal_dataset(path2data, transform = transform_val)

print(len(fetal_ds1))
print(len(fetal_ds2))
# Out:
# 999
# 999

# %%
img, mask = fetal_ds1[4]
print(img.shape, img.type(), torch.max(img))

print(mask.shape, mask.type(), torch.max(mask))
# Out:
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(0.9529)
# torch.Size([1, 128, 192]) torch.FloatTensor tensor(1.)

# %%
show_img_mask(np.squeeze(img),np.squeeze(mask))

# %%
from sklearn.model_selection import ShuffleSplit

# %%
sss = ShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 0)

indices = range(len(fetal_ds1))

for train_index, val_index in sss.split(indices):
    print(len(train_index))
    print("-"*10)
    print(len(val_index))
# Out:
# 799
# ----------
# 200

# %%
from torch.utils.data import Subset

train_ds = Subset(fetal_ds1, train_index)
print(len(train_ds))

val_ds = Subset(fetal_ds2, val_index)
print(len(val_ds))
# Out:
# 799
# 200

# %%
for img,mask in train_ds:
    show_img_mask(np.squeeze(img),np.squeeze(mask))
    break

# %%
for img,mask in val_ds:
    show_img_mask(np.squeeze(img),np.squeeze(mask))
    break

# %%
from torch.utils.data import DataLoader

train_dl = DataLoader(train_ds, batch_size=8, shuffle = True)

val_dl = DataLoader(val_ds, batch_size=8, shuffle = False)

# %%
for x,y in train_dl:
    print(x.shape, x.dtype)
    print(y.shape, y.dtype)
    break
for x,y in val_dl:
    print(x.shape, x.dtype)
    print(y.shape, y.dtype)
    break
# Out:
# torch.Size([8, 1, 128, 192]) torch.float32
# torch.Size([8, 1, 128, 192]) torch.float32
# torch.Size([8, 1, 128, 192]) torch.float32
# torch.Size([8, 1, 128, 192]) torch.float32

# %% [markdown]
# ## Defining the model

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class SegNet(nn.Module):
    def __init__(self, params):
        super(SegNet, self).__init__()
        C_in, H_in, W_in = params["input_shape"]
        init_f = params["initial_filters"]
        num_outputs = params["num_outputs"]
        
        self.conv1 = nn.Conv2d(C_in, init_f, kernel_size = 3, stride = 1, padding = 1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size = 3, stride = 1, padding = 1)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size = 3, stride = 1, padding = 1)
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size = 3, stride = 1, padding = 1)
        self.conv5 = nn.Conv2d(8*init_f, 16*init_f, kernel_size = 3, stride = 1, padding = 1)
        
        self.upsample = nn.Upsample(scale_factor = 2, mode = 'bilinear', align_corners = True)
        
        self.conv_up1 = nn.Conv2d(16*init_f,8*init_f, kernel_size= 3, padding = 1)
        self.conv_up2 = nn.Conv2d(8*init_f,4*init_f, kernel_size= 3, padding = 1)
        self.conv_up3 = nn.Conv2d(4*init_f,2*init_f, kernel_size= 3, padding = 1)
        self.conv_up4 = nn.Conv2d(2*init_f,init_f, kernel_size= 3, padding = 1)
        
        self.conv_out = nn.Conv2d(init_f, num_outputs, kernel_size=3, padding = 1)
        
    def forward(self,x):
        #Encoder
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        
        
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        
        
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        
        
        x = F.relu(self.conv5(x))
        
        # Decoder
        x = self.upsample(x)
        x = F.relu(self.conv_up1(x))
        
        
        x = self.upsample(x)
        x = F.relu(self.conv_up2(x))
        
        
        x = self.upsample(x)
        x = F.relu(self.conv_up3(x))
        
        
        x = self.upsample(x)
        x = F.relu(self.conv_up4(x))
        
        x = self.conv_out(x)
        
        return x

# %%
params_model = {
    "input_shape": (1,h,w), 
    "initial_filters": 16,
    "num_outputs": 1,
}
model = SegNet(params_model)

# %%
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else 'cpu')
model = model.to(device)
print(model)
# Out:
# SegNet(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (upsample): Upsample(scale_factor=2.0, mode=bilinear)
#   (conv_up1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up2): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_up4): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_out): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
import torch.nn.functional as F

def dice_loss(pred,target, smooth = 1e-5):
    intersection = (pred*target).sum(dim= (2,3))
    union = pred.sum(dim= (2,3)) + target.sum(dim= (2,3))
    dice = 2.0 * (intersection+smooth)/(union+smooth)
    loss = 1-dice
    return loss.sum(), dice.sum()

def loss_func(pred,target):
    bce = F.binary_cross_entropy_with_logits(pred, target, reduction = 'sum')
    pred = torch.sigmoid(pred)
    div,_ = dice_loss(pred,target)
    loss = bce + div
    return loss


def metric_batch(pred, target):
    pred = torch.sigmoid(pred)
    _,metric  = dice_loss(pred, target)
    return metric

# %%
def loss_batch(loss_func, output, target, opt = None):
    loss = loss_func(output,target)
    _, metric_b = dice_loss(torch.sigmoid(output), target)
    
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()
        
    return loss.item(), metric_b

# %%
from torch import optim
from tqdm import tqdm
opt = optim.Adam(model.parameters(), lr = 3e-4)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode = 'min', factor = 0.5, patience=20, verbose = 1)

# %%
def loss_epoch(model, loss_func, dataset_dl, sanity_check = False, opt= None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)
    
    for xb,yb in tqdm(dataset_dl):
        xb = xb.type(torch.float32).to(device)
#         print(device)
        yb  = yb.type(torch.float32).to(device)
        
        output = model(xb)
        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)
        running_loss += loss_b
        running_metric += metric_b
        
    loss = running_loss/len_data
    metric = running_metric/len_data
    
    return loss, metric

# %%
def get_lr(opt):
    
    for param in opt.param_groups:
        return param['lr']

# %%
import copy

def train_val(model, params):
    num_epochs=params["num_epochs"]
    loss_func=params["loss_func"]
    opt=params["optimizer"]
    train_dl=params["train_dl"]
    val_dl=params["val_dl"]
    sanity_check=params["sanity_check"]
    lr_scheduler=params["lr_scheduler"]
    path2weights=params["path2weights"]
    
    
    loss_history = {
        "train": [],
        "val": []
    }
    
    metric_history = {
        "train": [],
        "val": []
    }
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = float('inf')
    
    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        
        print(f"Epochs: {epoch+1}/{num_epochs} Current Learning Rate: {current_lr}")
        
        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt = opt)
        loss_history['train'].append(train_loss)
        metric_history["train"].append(train_metric)
        
        model.eval()
        with torch.no_grad():
            
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check, opt = None)
            loss_history['val'].append(val_loss)
            metric_history["val"].append(val_metric)
        
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print("Best model saved")
            
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("loading best wts")
            model.load_state_dict(best_model_wts)
            
        print("train loss: %.6f, dice: %.2f" %(train_loss,100*train_metric)) 
        print("val loss: %.6f, dice: %.2f" %(val_loss,100*val_metric))
        print("-"*10)
        
    model.load_state_dict(best_model_wts)
    
    return model, loss_history, metric_history

# %%
torch.cuda.empty_cache()

# %%
params_train={
"num_epochs": 75,
"optimizer": opt,
"loss_func": loss_func,
"train_dl": train_dl,
"val_dl": val_dl,
"sanity_check": False,
"lr_scheduler": lr_scheduler,
"path2weights": "./"+"weights.pt",
}

# %%
model,loss_hist,metric_hist=train_val(model,params_train)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epochs: 1/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.78it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.31it/s]
#   1%|          | 1/100 [00:00<00:19,  5.20it/s]
# Best model saved
# train loss: 13886.362651, dice: 36.19
# val loss: 9887.349336, dice: 48.36
# ----------
# Epochs: 2/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.05it/s]
#   1%|          | 1/100 [00:00<00:19,  5.07it/s]
# Best model saved
# train loss: 6995.963485, dice: 65.60
# val loss: 5984.022578, dice: 75.85
# ----------
# Epochs: 3/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.20it/s]
#   1%|          | 1/100 [00:00<00:19,  5.10it/s]
# Best model saved
# train loss: 5174.214059, dice: 75.12
# val loss: 4955.471758, dice: 76.91
# ----------
# Epochs: 4/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.89it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.75it/s]
#   1%|          | 1/100 [00:00<00:19,  5.09it/s]
# Best model saved
# train loss: 4532.066489, dice: 77.57
# val loss: 4622.733721, dice: 81.40
# ----------
# Epochs: 5/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.95it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.10it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 3676.977474, dice: 81.33
# val loss: 3446.459116, dice: 83.90
# ----------
# Epochs: 6/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.88it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.08it/s]
#   1%|          | 1/100 [00:00<00:19,  5.13it/s]
# Best model saved
# train loss: 3151.269594, dice: 83.76
# val loss: 3038.241895, dice: 84.35
# ----------
# Epochs: 7/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.30it/s]
#   1%|          | 1/100 [00:00<00:19,  5.04it/s]
# Best model saved
# train loss: 2819.384668, dice: 85.19
# val loss: 2758.448311, dice: 86.94
# ----------
# Epochs: 8/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.13it/s]
#   1%|          | 1/100 [00:00<00:19,  5.19it/s]
# train loss: 2559.428237, dice: 86.91
# val loss: 2981.107910, dice: 85.81
# ----------
# Epochs: 9/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:19<00:00,  5.02it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.64it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 2315.303358, dice: 88.04
# val loss: 2376.928628, dice: 88.86
# ----------
# Epochs: 10/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.93it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.19it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 2233.205859, dice: 88.85
# val loss: 2338.605752, dice: 88.56
# ----------
# Epochs: 11/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:21<00:00,  4.76it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.34it/s]
#   1%|          | 1/100 [00:00<00:18,  5.22it/s]
# Best model saved
# train loss: 2029.416189, dice: 89.89
# val loss: 2121.998931, dice: 87.71
# ----------
# Epochs: 12/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.09it/s]
#   1%|          | 1/100 [00:00<00:19,  5.06it/s]
# Best model saved
# train loss: 1792.984360, dice: 90.97
# val loss: 1935.097212, dice: 88.77
# ----------
# Epochs: 13/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.29it/s]
#   1%|          | 1/100 [00:00<00:18,  5.22it/s]
# Best model saved
# train loss: 1769.911856, dice: 91.27
# val loss: 1891.323408, dice: 90.58
# ----------
# Epochs: 14/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.91it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.36it/s]
#   1%|          | 1/100 [00:00<00:19,  5.15it/s]
# Best model saved
# train loss: 1703.549118, dice: 91.42
# val loss: 1881.544690, dice: 91.26
# ----------
# Epochs: 15/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.05it/s]
#   1%|          | 1/100 [00:00<00:19,  5.04it/s]
# Best model saved
# train loss: 1581.281387, dice: 92.25
# val loss: 1638.157654, dice: 91.93
# ----------
# Epochs: 16/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.33it/s]
#   1%|          | 1/100 [00:00<00:18,  5.24it/s]
# train loss: 1526.571224, dice: 92.46
# val loss: 1653.018640, dice: 91.99
# ----------
# Epochs: 17/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.29it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 1607.183321, dice: 92.29
# val loss: 1643.328340, dice: 90.86
# ----------
# Epochs: 18/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.94it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.65it/s]
#   1%|          | 1/100 [00:00<00:18,  5.21it/s]
# train loss: 1478.131169, dice: 92.70
# val loss: 1645.252505, dice: 91.43
# ----------
# Epochs: 19/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.89it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.32it/s]
#   1%|          | 1/100 [00:00<00:19,  5.10it/s]
# Best model saved
# train loss: 1429.174653, dice: 92.89
# val loss: 1587.619956, dice: 91.83
# ----------
# Epochs: 20/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.28it/s]
#   1%|          | 1/100 [00:00<00:19,  5.12it/s]
# Best model saved
# train loss: 1425.607726, dice: 93.00
# val loss: 1510.327522, dice: 93.03
# ----------
# Epochs: 21/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.09it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 1329.839480, dice: 93.32
# val loss: 1432.692312, dice: 93.04
# ----------
# Epochs: 22/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.88it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.10it/s]
#   1%|          | 1/100 [00:00<00:19,  5.08it/s]
# train loss: 1316.959193, dice: 93.49
# val loss: 1462.777458, dice: 92.73
# ----------
# Epochs: 23/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.88it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.80it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 1332.815594, dice: 93.57
# val loss: 1542.848049, dice: 92.37
# ----------
# Epochs: 24/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.95it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.12it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 1327.866953, dice: 93.52
# val loss: 1410.222429, dice: 93.20
# ----------
# Epochs: 25/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.90it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.09it/s]
#   1%|          | 1/100 [00:00<00:19,  5.20it/s]
# train loss: 1236.881423, dice: 94.04
# val loss: 1818.139172, dice: 90.96
# ----------
# Epochs: 26/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.35it/s]
#   1%|          | 1/100 [00:00<00:19,  5.01it/s]
# train loss: 1241.854016, dice: 93.75
# val loss: 1448.667356, dice: 93.46
# ----------
# Epochs: 27/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.33it/s]
#   1%|          | 1/100 [00:00<00:19,  5.18it/s]
# Best model saved
# train loss: 1234.994802, dice: 93.84
# val loss: 1337.360303, dice: 93.79
# ----------
# Epochs: 28/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.92it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.63it/s]
#   1%|          | 1/100 [00:00<00:19,  5.20it/s]
# train loss: 1295.490278, dice: 93.89
# val loss: 1541.887485, dice: 93.16
# ----------
# Epochs: 29/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.95it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.35it/s]
#   1%|          | 1/100 [00:00<00:19,  5.15it/s]
# train loss: 1193.086320, dice: 94.14
# val loss: 1970.093398, dice: 90.77
# ----------
# Epochs: 30/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.29it/s]
#   1%|          | 1/100 [00:00<00:19,  5.06it/s]
# train loss: 1161.449123, dice: 94.14
# val loss: 1421.349272, dice: 92.87
# ----------
# Epochs: 31/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.11it/s]
#   1%|          | 1/100 [00:00<00:19,  5.21it/s]
# train loss: 1148.570712, dice: 94.48
# val loss: 1420.759297, dice: 92.08
# ----------
# Epochs: 32/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.26it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 1136.308714, dice: 94.39
# val loss: 1321.301582, dice: 93.57
# ----------
# Epochs: 33/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.93it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.36it/s]
#   1%|          | 1/100 [00:00<00:19,  5.11it/s]
# train loss: 1099.712309, dice: 94.57
# val loss: 1560.720278, dice: 93.11
# ----------
# Epochs: 34/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.87it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.09it/s]
#   1%|          | 1/100 [00:00<00:19,  5.13it/s]
# train loss: 1125.913501, dice: 94.22
# val loss: 1361.483186, dice: 94.03
# ----------
# Epochs: 35/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.11it/s]
#   1%|          | 1/100 [00:00<00:19,  5.01it/s]
# train loss: 1086.774831, dice: 94.66
# val loss: 1321.547021, dice: 93.84
# ----------
# Epochs: 36/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:22<00:00,  4.48it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.24it/s]
#   1%|          | 1/100 [00:00<00:19,  5.10it/s]
# Best model saved
# train loss: 1059.686868, dice: 94.59
# val loss: 1279.661680, dice: 93.95
# ----------
# Epochs: 37/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:22<00:00,  4.49it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.79it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 1019.269142, dice: 94.95
# val loss: 1453.989260, dice: 93.95
# ----------
# Epochs: 38/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:21<00:00,  4.57it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.82it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 1005.207892, dice: 94.84
# val loss: 1330.866204, dice: 94.01
# ----------
# Epochs: 39/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.93it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.03it/s]
#   1%|          | 1/100 [00:00<00:19,  5.18it/s]
# train loss: 942.483040, dice: 95.14
# val loss: 1313.795208, dice: 94.17
# ----------
# Epochs: 40/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.37it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Best model saved
# train loss: 978.912585, dice: 95.00
# val loss: 1250.949192, dice: 94.08
# ----------
# Epochs: 41/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.34it/s]
#   1%|          | 1/100 [00:00<00:19,  5.12it/s]
# train loss: 1003.742789, dice: 95.17
# val loss: 1329.132822, dice: 93.71
# ----------
# Epochs: 42/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.02it/s]
#   1%|          | 1/100 [00:00<00:19,  5.07it/s]
# train loss: 988.163851, dice: 94.95
# val loss: 1324.446008, dice: 93.94
# ----------
# Epochs: 43/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.98it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.76it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 914.574662, dice: 95.27
# val loss: 1430.374316, dice: 93.76
# ----------
# Epochs: 44/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.91it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.74it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 1044.439649, dice: 94.79
# val loss: 1615.304729, dice: 92.70
# ----------
# Epochs: 45/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:22<00:00,  4.51it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.90it/s]
#   1%|          | 1/100 [00:00<00:19,  5.11it/s]
# train loss: 1008.517926, dice: 94.74
# val loss: 1367.954197, dice: 94.29
# ----------
# Epochs: 46/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.38it/s]
#   1%|          | 1/100 [00:00<00:19,  5.09it/s]
# train loss: 888.783961, dice: 95.43
# val loss: 1319.844453, dice: 93.78
# ----------
# Epochs: 47/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.79it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.33it/s]
#   1%|          | 1/100 [00:00<00:18,  5.23it/s]
# train loss: 847.503230, dice: 95.52
# val loss: 1316.163652, dice: 94.66
# ----------
# Epochs: 48/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.94it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.60it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 843.952484, dice: 95.58
# val loss: 1348.240610, dice: 94.29
# ----------
# Epochs: 49/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.93it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.35it/s]
#   1%|          | 1/100 [00:00<00:19,  5.15it/s]
# train loss: 833.509491, dice: 95.65
# val loss: 1356.881196, dice: 94.13
# ----------
# Epochs: 50/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.87it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.36it/s]
#   1%|          | 1/100 [00:00<00:19,  5.16it/s]
# train loss: 811.372148, dice: 95.65
# val loss: 1301.921453, dice: 94.58
# ----------
# Epochs: 51/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.03it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 810.991003, dice: 95.71
# val loss: 1328.912976, dice: 94.52
# ----------
# Epochs: 52/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.86it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.04it/s]
#   1%|          | 1/100 [00:00<00:19,  5.19it/s]
# train loss: 791.070724, dice: 95.82
# val loss: 1272.072371, dice: 94.69
# ----------
# Epochs: 53/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.92it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.85it/s]
#   1%|          | 1/100 [00:00<00:19,  5.07it/s]
# train loss: 860.464505, dice: 95.58
# val loss: 1343.832402, dice: 94.14
# ----------
# Epochs: 54/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.96it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.37it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 880.344966, dice: 95.43
# val loss: 1440.254756, dice: 94.24
# ----------
# Epochs: 55/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.08it/s]
#   1%|          | 1/100 [00:00<00:19,  5.12it/s]
# train loss: 767.995231, dice: 95.92
# val loss: 1351.829473, dice: 94.51
# ----------
# Epochs: 56/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.86it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.37it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 761.998497, dice: 95.94
# val loss: 1252.224646, dice: 94.71
# ----------
# Epochs: 57/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.31it/s]
#   1%|          | 1/100 [00:00<00:19,  5.18it/s]
# train loss: 745.248459, dice: 95.99
# val loss: 1301.730134, dice: 94.73
# ----------
# Epochs: 58/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.90it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.51it/s]
#   1%|          | 1/100 [00:00<00:18,  5.22it/s]
# train loss: 731.460947, dice: 96.09
# val loss: 1325.833467, dice: 94.66
# ----------
# Epochs: 59/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.14it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 779.538466, dice: 95.90
# val loss: 1382.254646, dice: 94.55
# ----------
# Epochs: 60/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:21<00:00,  4.68it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.33it/s]
#   1%|          | 1/100 [00:00<00:19,  5.20it/s]
# train loss: 751.485586, dice: 95.99
# val loss: 1311.565959, dice: 94.57
# ----------
# Epochs: 61/75 Current Learning Rate: 0.0003
# 100%|██████████| 100/100 [00:21<00:00,  4.71it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.96it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch    61: reducing learning rate of group 0 to 1.5000e-04.
# loading best wts
# train loss: 714.029597, dice: 96.16
# val loss: 1316.019531, dice: 94.73
# ----------
# Epochs: 62/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:21<00:00,  4.75it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.15it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 868.054728, dice: 95.38
# val loss: 1253.939939, dice: 94.29
# ----------
# Epochs: 63/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:21<00:00,  4.72it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.06it/s]
#   1%|          | 1/100 [00:00<00:19,  5.06it/s]
# train loss: 936.221034, dice: 95.25
# val loss: 1325.119412, dice: 94.15
# ----------
# Epochs: 64/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.97it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.03it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 863.308020, dice: 95.51
# val loss: 1265.686768, dice: 94.38
# ----------
# Epochs: 65/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.34it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 829.476181, dice: 95.62
# val loss: 1288.756951, dice: 94.38
# ----------
# Epochs: 66/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.86it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.35it/s]
#   1%|          | 1/100 [00:00<00:19,  5.11it/s]
# Best model saved
# train loss: 819.967867, dice: 95.69
# val loss: 1245.823772, dice: 94.60
# ----------
# Epochs: 67/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.83it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.05it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 850.178459, dice: 95.66
# val loss: 1420.785986, dice: 93.78
# ----------
# Epochs: 68/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.81it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.26it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 830.180944, dice: 95.62
# val loss: 1290.261897, dice: 94.55
# ----------
# Epochs: 69/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.96it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.33it/s]
#   1%|          | 1/100 [00:00<00:19,  5.19it/s]
# train loss: 794.667489, dice: 95.80
# val loss: 1248.908577, dice: 94.68
# ----------
# Epochs: 70/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.85it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.10it/s]
#   1%|          | 1/100 [00:00<00:18,  5.26it/s]
# train loss: 925.142083, dice: 95.39
# val loss: 1268.627146, dice: 94.51
# ----------
# Epochs: 71/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.21it/s]
#   1%|          | 1/100 [00:00<00:19,  5.20it/s]
# train loss: 782.576704, dice: 95.86
# val loss: 1293.388667, dice: 94.58
# ----------
# Epochs: 72/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.84it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.38it/s]
#   1%|          | 1/100 [00:00<00:19,  5.12it/s]
# train loss: 773.804035, dice: 95.93
# val loss: 1290.540774, dice: 94.76
# ----------
# Epochs: 73/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.89it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.26it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 746.871595, dice: 96.02
# val loss: 1319.994331, dice: 94.82
# ----------
# Epochs: 74/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.82it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.22it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]
# train loss: 770.602179, dice: 95.92
# val loss: 1256.867876, dice: 94.82
# ----------
# Epochs: 75/75 Current Learning Rate: 0.00015
# 100%|██████████| 100/100 [00:20<00:00,  4.77it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.23it/s]
# train loss: 737.747002, dice: 96.06
# val loss: 1321.498752, dice: 94.70
# ----------

# %%
num_epochs = params_train['num_epochs']

plt.figure()
plt.plot(range(1, num_epochs+1), loss_hist['train'], label = 'train')

plt.plot(range(1, num_epochs+1), loss_hist['val'], label = 'val')
plt.xlabel("Numer of Epochs")
plt.ylabel("Loss")
plt.title("Train_val_loss")
plt.legend()

# %%
num_epochs = params_train['num_epochs']

plt.figure()
plt.plot(range(1, num_epochs+1), metric_hist['train'], label = 'train')

plt.plot(range(1, num_epochs+1), metric_hist['val'], label = 'val')
plt.xlabel("Numer of Epochs")
plt.ylabel("Loss")
plt.title("Accuracy(Dice)")
plt.legend()

# %% [markdown]
# ### Deploying the Model

# %%
path2testdata = '../input/fetal-detection-and-test/test_set/test_set'

img_list = os.listdir(path2testdata)

# %%
rnd_imgs = np.random.choice(img_list, 4)

# %%
for i in rnd_imgs:
    model.eval()
    with torch.no_grad():
        img = Image.open(os.path.join(path2testdata, i))
        img = img.resize((w,h))
        img_t = to_tensor(img).unsqueeze(0).to(device)
        pred = model(img_t)
        pred=torch.sigmoid(pred)[0]
        mask_pred= (pred[0]>=0.5)
    plt.figure(figsize=(10,10))
    plt.subplot(1, 3, 1)
    plt.imshow(img, cmap="gray")
    plt.subplot(1, 3, 2)
    plt.imshow(mask_pred.cpu().detach().numpy(), cmap="gray")
    plt.subplot(1, 3, 3)
    show_img_mask(img, mask_pred.cpu().detach().numpy())
